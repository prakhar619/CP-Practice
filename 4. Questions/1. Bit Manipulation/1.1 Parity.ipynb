// %% [markdown]
// ##### Chapter 1: Bit Manipulation

// %% [markdown]
// ### 1. Computing the Parity of a word

// %% [markdown]
// >The parity of a binary word is 1 if the number of 1s in the word odd; otherwise it is 0
// Eg:   1011 is 1
// Eg:   1010 is 0

// %% [markdown]
// *Leetcode Link*:

// %% [markdown]
// **Verified Best Solution**:

// %% [markdown]
// #### Method 1:
// Time Complexity: O(n)
// Space Complexity: O(1)
// ###### where n is number of bits in input

// %%
bool parity1(long long x)
{
    bool result = false;
    while (x != 0)
    {
        if(x & 1)
        {
            result = !result;
        }
        x >>= 1;
    }
    return result;
}

// %% [markdown]
// #### Method 2:
// Time Complexity: O(k)
// Space Complexity: O(1)
// ###### where k is number of set bit in input

// %%
bool parity2(long long x)
{
    bool result = false;
    while (x != 0)
    {
        result = !result;
        x = x & (x - 1);
    }
    return result;
}

// %% [markdown]
// #### Method 3:
// Time Complexity: O(n/k)
// Space Complexity: O(n/k)  (verify)
// ###### where n is number of bit in input and k is the mask/bit size of lookup table entry

// %%
int precomputedParity(long long x)
{
    //00, 11 -> Parity = 0
    if(x == 0 || x == 3)
    {
        return 0;
    }
    //01, 10 => Parity = 1
    else if(x == 1 || x == 2)
    {
        return 1;
    }
    else 
    {
        //one hexadecimal digit = 4 bits
        //0x3 = 0011
        int mask = 0x3;
        return precomputedParity(x & mask) ^ precomputedParity(x >> 2);
    }
}

// %%
bool parity3(long long x)
{
    if(precomputedParity(x) == 1)
    return true;
    return false;
}

//with enough entries in lookup table, can be converted to O(1)

// %% [markdown]
// #### Method 4:
// Time Complexity: O(log n)
// Space Complexity: O(log n)  (verify)
// ###### where n is number of bit in input

// %%
bool parity4(long long x)
{
    int wordSize = sizeof(long long) * 8;
    unsigned long long mask = 0xFFFFFFFFFFFFFFFF;   //0xFF_FF_FF_FF_FF_FF_FF_FF
    while(x != 0 && x != 1)
    {
        wordSize /= 2;

        x = (x & (mask >> wordSize)) ^ ((x >> wordSize) & mask);
        mask = mask >> wordSize;
    }
    if(x == 1)
    return true;
    return false;
}

// %% [markdown]
// ### Test

// %%
#include <iostream>
using namespace std;
for(int i = 0; i < 1000; i++)
{
    bool check1 = parity1(i);
    bool check2 = parity2(i);
    bool check3 = parity3(i);
    bool check4 = parity4(i);

    if(check1 == check2 && check2 == check3 && check3 == check4)
    {
        cout << "Correct for:\t" << i << ":\tParity:" << check1 << endl;
    }
    else
    {
        cout << "Error for:\t" << i << ":\tParity:" << check1 << " " << check2 << " " << check3 << " " << check4 << endl;
    }
}
// Out:
// Correct for:	0:	Parity:0
// Correct for:	1:	Parity:1
// Correct for:	2:	Parity:1
// Correct for:	3:	Parity:0
// Correct for:	4:	Parity:1
// Correct for:	5:	Parity:0
// Correct for:	6:	Parity:0
// Correct for:	7:	Parity:1
// Correct for:	8:	Parity:1
// Correct for:	9:	Parity:0
// Correct for:	10:	Parity:0
// Correct for:	11:	Parity:1
// Correct for:	12:	Parity:0
// Correct for:	13:	Parity:1
// Correct for:	14:	Parity:1
// Correct for:	15:	Parity:0
// Correct for:	16:	Parity:1
// Correct for:	17:	Parity:0
// Correct for:	18:	Parity:0
// Correct for:	19:	Parity:1
// Correct for:	20:	Parity:0
// Correct for:	21:	Parity:1
// Correct for:	22:	Parity:1
// Correct for:	23:	Parity:0
// Correct for:	24:	Parity:0
// Correct for:	25:	Parity:1
// Correct for:	26:	Parity:1
// Correct for:	27:	Parity:0
// Correct for:	28:	Parity:1
// Correct for:	29:	Parity:0
// Correct for:	30:	Parity:0
// Correct for:	31:	Parity:1
// Correct for:	32:	Parity:1
// Correct for:	33:	Parity:0
// Correct for:	34:	Parity:0
// Correct for:	35:	Parity:1
// Correct for:	36:	Parity:0
// Correct for:	37:	Parity:1
// Correct for:	38:	Parity:1
// Correct for:	39:	Parity:0
// Correct for:	40:	Parity:0
// Correct for:	41:	Parity:1
// Correct for:	42:	Parity:1
// Correct for:	43:	Parity:0
// Correct for:	44:	Parity:1
// Correct for:	45:	Parity:0
// Correct for:	46:	Parity:0
// Correct for:	47:	Parity:1
// Correct for:	48:	Parity:0
// Correct for:	49:	Parity:1
// Correct for:	50:	Parity:1
// Correct for:	51:	Parity:0
// Correct for:	52:	Parity:1
// Correct for:	53:	Parity:0
// Correct for:	54:	Parity:0
// Correct for:	55:	Parity:1
// Correct for:	56:	Parity:1
// Correct for:	57:	Parity:0
// Correct for:	58:	Parity:0
// Correct for:	59:	Parity:1
// Correct for:	60:	Parity:0
// Correct for:	61:	Parity:1
// Correct for:	62:	Parity:1
// Correct for:	63:	Parity:0
// Correct for:	64:	Parity:1
// Correct for:	65:	Parity:0
// Correct for:	66:	Parity:0
// Correct for:	67:	Parity:1
// Correct for:	68:	Parity:0
// Correct for:	69:	Parity:1
// Correct for:	70:	Parity:1
// Correct for:	71:	Parity:0
// Correct for:	72:	Parity:0
// Correct for:	73:	Parity:1
// Correct for:	74:	Parity:1
// Correct for:	75:	Parity:0
// Correct for:	76:	Parity:1
// Correct for:	77:	Parity:0
// Correct for:	78:	Parity:0
// Correct for:	79:	Parity:1
// Correct for:	80:	Parity:0
// Correct for:	81:	Parity:1
// Correct for:	82:	Parity:1
// Correct for:	83:	Parity:0
// Correct for:	84:	Parity:1
// Correct for:	85:	Parity:0
// Correct for:	86:	Parity:0
// Correct for:	87:	Parity:1
// Correct for:	88:	Parity:1
// Correct for:	89:	Parity:0
// Correct for:	90:	Parity:0
// Correct for:	91:	Parity:1
// Correct for:	92:	Parity:0
// Correct for:	93:	Parity:1
// Correct for:	94:	Parity:1
// Correct for:	95:	Parity:0
// Correct for:	96:	Parity:0
// Correct for:	97:	Parity:1
// Correct for:	98:	Parity:1
// Correct for:	99:	Parity:0
// Correct for:	100:	Parity:1
// Correct for:	101:	Parity:0
// Correct for:	102:	Parity:0
// Correct for:	103:	Parity:1
// Correct for:	104:	Parity:1
// Correct for:	105:	Parity:0
// Correct for:	106:	Parity:0
// Correct for:	107:	Parity:1
// Correct for:	108:	Parity:0
// Correct for:	109:	Parity:1
// Correct for:	110:	Parity:1
// Correct for:	111:	Parity:0
// Correct for:	112:	Parity:1
// Correct for:	113:	Parity:0
// Correct for:	114:	Parity:0
// Correct for:	115:	Parity:1
// Correct for:	116:	Parity:0
// Correct for:	117:	Parity:1
// Correct for:	118:	Parity:1
// Correct for:	119:	Parity:0
// Correct for:	120:	Parity:0
// Correct for:	121:	Parity:1
// Correct for:	122:	Parity:1
// Correct for:	123:	Parity:0
// Correct for:	124:	Parity:1
// Correct for:	125:	Parity:0
// Correct for:	126:	Parity:0
// Correct for:	127:	Parity:1
// Correct for:	128:	Parity:1
// Correct for:	129:	Parity:0
// Correct for:	130:	Parity:0
// Correct for:	131:	Parity:1
// Correct for:	132:	Parity:0
// Correct for:	133:	Parity:1
// Correct for:	134:	Parity:1
// Correct for:	135:	Parity:0
// Correct for:	136:	Parity:0
// Correct for:	137:	Parity:1
// Correct for:	138:	Parity:1
// Correct for:	139:	Parity:0
// Correct for:	140:	Parity:1
// Correct for:	141:	Parity:0
// Correct for:	142:	Parity:0
// Correct for:	143:	Parity:1
// Correct for:	144:	Parity:0
// Correct for:	145:	Parity:1
// Correct for:	146:	Parity:1
// Correct for:	147:	Parity:0
// Correct for:	148:	Parity:1
// Correct for:	149:	Parity:0
// Correct for:	150:	Parity:0
// Correct for:	151:	Parity:1
// Correct for:	152:	Parity:1
// Correct for:	153:	Parity:0
// Correct for:	154:	Parity:0
// Correct for:	155:	Parity:1
// Correct for:	156:	Parity:0
// Correct for:	157:	Parity:1
// Correct for:	158:	Parity:1
// Correct for:	159:	Parity:0
// Correct for:	160:	Parity:0
// Correct for:	161:	Parity:1
// Correct for:	162:	Parity:1
// Correct for:	163:	Parity:0
// Correct for:	164:	Parity:1
// Correct for:	165:	Parity:0
// Correct for:	166:	Parity:0
// Correct for:	167:	Parity:1
// Correct for:	168:	Parity:1
// Correct for:	169:	Parity:0
// Correct for:	170:	Parity:0
// Correct for:	171:	Parity:1
// Correct for:	172:	Parity:0
// Correct for:	173:	Parity:1
// Correct for:	174:	Parity:1
// Correct for:	175:	Parity:0
// Correct for:	176:	Parity:1
// Correct for:	177:	Parity:0
// Correct for:	178:	Parity:0
// Correct for:	179:	Parity:1
// Correct for:	180:	Parity:0
// Correct for:	181:	Parity:1
// Correct for:	182:	Parity:1
// Correct for:	183:	Parity:0
// Correct for:	184:	Parity:0
// Correct for:	185:	Parity:1
// Correct for:	186:	Parity:1
// Correct for:	187:	Parity:0
// Correct for:	188:	Parity:1
// Correct for:	189:	Parity:0
// Correct for:	190:	Parity:0
// Correct for:	191:	Parity:1
// Correct for:	192:	Parity:0
// Correct for:	193:	Parity:1
// Correct for:	194:	Parity:1
// Correct for:	195:	Parity:0
// Correct for:	196:	Parity:1
// Correct for:	197:	Parity:0
// Correct for:	198:	Parity:0
// Correct for:	199:	Parity:1
// Correct for:	200:	Parity:1
// Correct for:	201:	Parity:0
// Correct for:	202:	Parity:0
// Correct for:	203:	Parity:1
// Correct for:	204:	Parity:0
// Correct for:	205:	Parity:1
// Correct for:	206:	Parity:1
// Correct for:	207:	Parity:0
// Correct for:	208:	Parity:1
// Correct for:	209:	Parity:0
// Correct for:	210:	Parity:0
// Correct for:	211:	Parity:1
// Correct for:	212:	Parity:0
// Correct for:	213:	Parity:1
// Correct for:	214:	Parity:1
// Correct for:	215:	Parity:0
// Correct for:	216:	Parity:0
// Correct for:	217:	Parity:1
// Correct for:	218:	Parity:1
// Correct for:	219:	Parity:0
// Correct for:	220:	Parity:1
// Correct for:	221:	Parity:0
// Correct for:	222:	Parity:0
// Correct for:	223:	Parity:1
// Correct for:	224:	Parity:1
// Correct for:	225:	Parity:0
// Correct for:	226:	Parity:0
// Correct for:	227:	Parity:1
// Correct for:	228:	Parity:0
// Correct for:	229:	Parity:1
// Correct for:	230:	Parity:1
// Correct for:	231:	Parity:0
// Correct for:	232:	Parity:0
// Correct for:	233:	Parity:1
// Correct for:	234:	Parity:1
// Correct for:	235:	Parity:0
// Correct for:	236:	Parity:1
// Correct for:	237:	Parity:0
// Correct for:	238:	Parity:0
// Correct for:	239:	Parity:1
// Correct for:	240:	Parity:0
// Correct for:	241:	Parity:1
// Correct for:	242:	Parity:1
// Correct for:	243:	Parity:0
// Correct for:	244:	Parity:1
// Correct for:	245:	Parity:0
// Correct for:	246:	Parity:0
// Correct for:	247:	Parity:1
// Correct for:	248:	Parity:1
// Correct for:	249:	Parity:0
// Correct for:	250:	Parity:0
// Correct for:	251:	Parity:1
// Correct for:	252:	Parity:0
// Correct for:	253:	Parity:1
// Correct for:	254:	Parity:1
// Correct for:	255:	Parity:0
// Correct for:	256:	Parity:1
// Correct for:	257:	Parity:0
// Correct for:	258:	Parity:0
// Correct for:	259:	Parity:1
// Correct for:	260:	Parity:0
// Correct for:	261:	Parity:1
// Correct for:	262:	Parity:1
// Correct for:	263:	Parity:0
// Correct for:	264:	Parity:0
// Correct for:	265:	Parity:1
// Correct for:	266:	Parity:1
// Correct for:	267:	Parity:0
// Correct for:	268:	Parity:1
// Correct for:	269:	Parity:0
// Correct for:	270:	Parity:0
// Correct for:	271:	Parity:1
// Correct for:	272:	Parity:0
// Correct for:	273:	Parity:1
// Correct for:	274:	Parity:1
// Correct for:	275:	Parity:0
// Correct for:	276:	Parity:1
// Correct for:	277:	Parity:0
// Correct for:	278:	Parity:0
// Correct for:	279:	Parity:1
// Correct for:	280:	Parity:1
// Correct for:	281:	Parity:0
// Correct for:	282:	Parity:0
// Correct for:	283:	Parity:1
// Correct for:	284:	Parity:0
// Correct for:	285:	Parity:1
// Correct for:	286:	Parity:1
// Correct for:	287:	Parity:0
// Correct for:	288:	Parity:0
// Correct for:	289:	Parity:1
// Correct for:	290:	Parity:1
// Correct for:	291:	Parity:0
// Correct for:	292:	Parity:1
// Correct for:	293:	Parity:0
// Correct for:	294:	Parity:0
// Correct for:	295:	Parity:1
// Correct for:	296:	Parity:1
// Correct for:	297:	Parity:0
// Correct for:	298:	Parity:0
// Correct for:	299:	Parity:1
// Correct for:	300:	Parity:0
// Correct for:	301:	Parity:1
// Correct for:	302:	Parity:1
// Correct for:	303:	Parity:0
// Correct for:	304:	Parity:1
// Correct for:	305:	Parity:0
// Correct for:	306:	Parity:0
// Correct for:	307:	Parity:1
// Correct for:	308:	Parity:0
// Correct for:	309:	Parity:1
// Correct for:	310:	Parity:1
// Correct for:	311:	Parity:0
// Correct for:	312:	Parity:0
// Correct for:	313:	Parity:1
// Correct for:	314:	Parity:1
// Correct for:	315:	Parity:0
// Correct for:	316:	Parity:1
// Correct for:	317:	Parity:0
// Correct for:	318:	Parity:0
// Correct for:	319:	Parity:1
// Correct for:	320:	Parity:0
// Correct for:	321:	Parity:1
// Correct for:	322:	Parity:1
// Correct for:	323:	Parity:0
// Correct for:	324:	Parity:1
// Correct for:	325:	Parity:0
// Correct for:	326:	Parity:0
// Correct for:	327:	Parity:1
// Correct for:	328:	Parity:1
// Correct for:	329:	Parity:0
// Correct for:	330:	Parity:0
// Correct for:	331:	Parity:1
// Correct for:	332:	Parity:0
// Correct for:	333:	Parity:1
// Correct for:	334:	Parity:1
// Correct for:	335:	Parity:0
// Correct for:	336:	Parity:1
// Correct for:	337:	Parity:0
// Correct for:	338:	Parity:0
// Correct for:	339:	Parity:1
// Correct for:	340:	Parity:0
// Correct for:	341:	Parity:1
// Correct for:	342:	Parity:1
// Correct for:	343:	Parity:0
// Correct for:	344:	Parity:0
// Correct for:	345:	Parity:1
// Correct for:	346:	Parity:1
// Correct for:	347:	Parity:0
// Correct for:	348:	Parity:1
// Correct for:	349:	Parity:0
// Correct for:	350:	Parity:0
// Correct for:	351:	Parity:1
// Correct for:	352:	Parity:1
// Correct for:	353:	Parity:0
// Correct for:	354:	Parity:0
// Correct for:	355:	Parity:1
// Correct for:	356:	Parity:0
// Correct for:	357:	Parity:1
// Correct for:	358:	Parity:1
// Correct for:	359:	Parity:0
// Correct for:	360:	Parity:0
// Correct for:	361:	Parity:1
// Correct for:	362:	Parity:1
// Correct for:	363:	Parity:0
// Correct for:	364:	Parity:1
// Correct for:	365:	Parity:0
// Correct for:	366:	Parity:0
// Correct for:	367:	Parity:1
// Correct for:	368:	Parity:0
// Correct for:	369:	Parity:1
// Correct for:	370:	Parity:1
// Correct for:	371:	Parity:0
// Correct for:	372:	Parity:1
// Correct for:	373:	Parity:0
// Correct for:	374:	Parity:0
// Correct for:	375:	Parity:1
// Correct for:	376:	Parity:1
// Correct for:	377:	Parity:0
// Correct for:	378:	Parity:0
// Correct for:	379:	Parity:1
// Correct for:	380:	Parity:0
// Correct for:	381:	Parity:1
// Correct for:	382:	Parity:1
// Correct for:	383:	Parity:0
// Correct for:	384:	Parity:0
// Correct for:	385:	Parity:1
// Correct for:	386:	Parity:1
// Correct for:	387:	Parity:0
// Correct for:	388:	Parity:1
// Correct for:	389:	Parity:0
// Correct for:	390:	Parity:0
// Correct for:	391:	Parity:1
// Correct for:	392:	Parity:1
// Correct for:	393:	Parity:0
// Correct for:	394:	Parity:0
// Correct for:	395:	Parity:1
// Correct for:	396:	Parity:0
// Correct for:	397:	Parity:1
// Correct for:	398:	Parity:1
// Correct for:	399:	Parity:0
// Correct for:	400:	Parity:1
// Correct for:	401:	Parity:0
// Correct for:	402:	Parity:0
// Correct for:	403:	Parity:1
// Correct for:	404:	Parity:0
// Correct for:	405:	Parity:1
// Correct for:	406:	Parity:1
// Correct for:	407:	Parity:0
// Correct for:	408:	Parity:0
// Correct for:	409:	Parity:1
// Correct for:	410:	Parity:1
// Correct for:	411:	Parity:0
// Correct for:	412:	Parity:1
// Correct for:	413:	Parity:0
// Correct for:	414:	Parity:0
// Correct for:	415:	Parity:1
// Correct for:	416:	Parity:1
// Correct for:	417:	Parity:0
// Correct for:	418:	Parity:0
// Correct for:	419:	Parity:1
// Correct for:	420:	Parity:0
// Correct for:	421:	Parity:1
// Correct for:	422:	Parity:1
// Correct for:	423:	Parity:0
// Correct for:	424:	Parity:0
// Correct for:	425:	Parity:1
// Correct for:	426:	Parity:1
// Correct for:	427:	Parity:0
// Correct for:	428:	Parity:1
// Correct for:	429:	Parity:0
// Correct for:	430:	Parity:0
// Correct for:	431:	Parity:1
// Correct for:	432:	Parity:0
// Correct for:	433:	Parity:1
// Correct for:	434:	Parity:1
// Correct for:	435:	Parity:0
// Correct for:	436:	Parity:1
// Correct for:	437:	Parity:0
// Correct for:	438:	Parity:0
// Correct for:	439:	Parity:1
// Correct for:	440:	Parity:1
// Correct for:	441:	Parity:0
// Correct for:	442:	Parity:0
// Correct for:	443:	Parity:1
// Correct for:	444:	Parity:0
// Correct for:	445:	Parity:1
// Correct for:	446:	Parity:1
// Correct for:	447:	Parity:0
// Correct for:	448:	Parity:1
// Correct for:	449:	Parity:0
// Correct for:	450:	Parity:0
// Correct for:	451:	Parity:1
// Correct for:	452:	Parity:0
// Correct for:	453:	Parity:1
// Correct for:	454:	Parity:1
// Correct for:	455:	Parity:0
// Correct for:	456:	Parity:0
// Correct for:	457:	Parity:1
// Correct for:	458:	Parity:1
// Correct for:	459:	Parity:0
// Correct for:	460:	Parity:1
// Correct for:	461:	Parity:0
// Correct for:	462:	Parity:0
// Correct for:	463:	Parity:1
// Correct for:	464:	Parity:0
// Correct for:	465:	Parity:1
// Correct for:	466:	Parity:1
// Correct for:	467:	Parity:0
// Correct for:	468:	Parity:1
// Correct for:	469:	Parity:0
// Correct for:	470:	Parity:0
// Correct for:	471:	Parity:1
// Correct for:	472:	Parity:1
// Correct for:	473:	Parity:0
// Correct for:	474:	Parity:0
// Correct for:	475:	Parity:1
// Correct for:	476:	Parity:0
// Correct for:	477:	Parity:1
// Correct for:	478:	Parity:1
// Correct for:	479:	Parity:0
// Correct for:	480:	Parity:0
// Correct for:	481:	Parity:1
// Correct for:	482:	Parity:1
// Correct for:	483:	Parity:0
// Correct for:	484:	Parity:1
// Correct for:	485:	Parity:0
// Correct for:	486:	Parity:0
// Correct for:	487:	Parity:1
// Correct for:	488:	Parity:1
// Correct for:	489:	Parity:0
// Correct for:	490:	Parity:0
// Correct for:	491:	Parity:1
// Correct for:	492:	Parity:0
// Correct for:	493:	Parity:1
// Correct for:	494:	Parity:1
// Correct for:	495:	Parity:0
// Correct for:	496:	Parity:1
// Correct for:	497:	Parity:0
// Correct for:	498:	Parity:0
// Correct for:	499:	Parity:1
// Correct for:	500:	Parity:0
// Correct for:	501:	Parity:1
// Correct for:	502:	Parity:1
// Correct for:	503:	Parity:0
// Correct for:	504:	Parity:0
// Correct for:	505:	Parity:1
// Correct for:	506:	Parity:1
// Correct for:	507:	Parity:0
// Correct for:	508:	Parity:1
// Correct for:	509:	Parity:0
// Correct for:	510:	Parity:0
// Correct for:	511:	Parity:1
// Correct for:	512:	Parity:1
// Correct for:	513:	Parity:0
// Correct for:	514:	Parity:0
// Correct for:	515:	Parity:1
// Correct for:	516:	Parity:0
// Correct for:	517:	Parity:1
// Correct for:	518:	Parity:1
// Correct for:	519:	Parity:0
// Correct for:	520:	Parity:0
// Correct for:	521:	Parity:1
// Correct for:	522:	Parity:1
// Correct for:	523:	Parity:0
// Correct for:	524:	Parity:1
// Correct for:	525:	Parity:0
// Correct for:	526:	Parity:0
// Correct for:	527:	Parity:1
// Correct for:	528:	Parity:0
// Correct for:	529:	Parity:1
// Correct for:	530:	Parity:1
// Correct for:	531:	Parity:0
// Correct for:	532:	Parity:1
// Correct for:	533:	Parity:0
// Correct for:	534:	Parity:0
// Correct for:	535:	Parity:1
// Correct for:	536:	Parity:1
// Correct for:	537:	Parity:0
// Correct for:	538:	Parity:0
// Correct for:	539:	Parity:1
// Correct for:	540:	Parity:0
// Correct for:	541:	Parity:1
// Correct for:	542:	Parity:1
// Correct for:	543:	Parity:0
// Correct for:	544:	Parity:0
// Correct for:	545:	Parity:1
// Correct for:	546:	Parity:1
// Correct for:	547:	Parity:0
// Correct for:	548:	Parity:1
// Correct for:	549:	Parity:0
// Correct for:	550:	Parity:0
// Correct for:	551:	Parity:1
// Correct for:	552:	Parity:1
// Correct for:	553:	Parity:0
// Correct for:	554:	Parity:0
// Correct for:	555:	Parity:1
// Correct for:	556:	Parity:0
// Correct for:	557:	Parity:1
// Correct for:	558:	Parity:1
// Correct for:	559:	Parity:0
// Correct for:	560:	Parity:1
// Correct for:	561:	Parity:0
// Correct for:	562:	Parity:0
// Correct for:	563:	Parity:1
// Correct for:	564:	Parity:0
// Correct for:	565:	Parity:1
// Correct for:	566:	Parity:1
// Correct for:	567:	Parity:0
// Correct for:	568:	Parity:0
// Correct for:	569:	Parity:1
// Correct for:	570:	Parity:1
// Correct for:	571:	Parity:0
// Correct for:	572:	Parity:1
// Correct for:	573:	Parity:0
// Correct for:	574:	Parity:0
// Correct for:	575:	Parity:1
// Correct for:	576:	Parity:0
// Correct for:	577:	Parity:1
// Correct for:	578:	Parity:1
// Correct for:	579:	Parity:0
// Correct for:	580:	Parity:1
// Correct for:	581:	Parity:0
// Correct for:	582:	Parity:0
// Correct for:	583:	Parity:1
// Correct for:	584:	Parity:1
// Correct for:	585:	Parity:0
// Correct for:	586:	Parity:0
// Correct for:	587:	Parity:1
// Correct for:	588:	Parity:0
// Correct for:	589:	Parity:1
// Correct for:	590:	Parity:1
// Correct for:	591:	Parity:0
// Correct for:	592:	Parity:1
// Correct for:	593:	Parity:0
// Correct for:	594:	Parity:0
// Correct for:	595:	Parity:1
// Correct for:	596:	Parity:0
// Correct for:	597:	Parity:1
// Correct for:	598:	Parity:1
// Correct for:	599:	Parity:0
// Correct for:	600:	Parity:0
// Correct for:	601:	Parity:1
// Correct for:	602:	Parity:1
// Correct for:	603:	Parity:0
// Correct for:	604:	Parity:1
// Correct for:	605:	Parity:0
// Correct for:	606:	Parity:0
// Correct for:	607:	Parity:1
// Correct for:	608:	Parity:1
// Correct for:	609:	Parity:0
// Correct for:	610:	Parity:0
// Correct for:	611:	Parity:1
// Correct for:	612:	Parity:0
// Correct for:	613:	Parity:1
// Correct for:	614:	Parity:1
// Correct for:	615:	Parity:0
// Correct for:	616:	Parity:0
// Correct for:	617:	Parity:1
// Correct for:	618:	Parity:1
// Correct for:	619:	Parity:0
// Correct for:	620:	Parity:1
// Correct for:	621:	Parity:0
// Correct for:	622:	Parity:0
// Correct for:	623:	Parity:1
// Correct for:	624:	Parity:0
// Correct for:	625:	Parity:1
// Correct for:	626:	Parity:1
// Correct for:	627:	Parity:0
// Correct for:	628:	Parity:1
// Correct for:	629:	Parity:0
// Correct for:	630:	Parity:0
// Correct for:	631:	Parity:1
// Correct for:	632:	Parity:1
// Correct for:	633:	Parity:0
// Correct for:	634:	Parity:0
// Correct for:	635:	Parity:1
// Correct for:	636:	Parity:0
// Correct for:	637:	Parity:1
// Correct for:	638:	Parity:1
// Correct for:	639:	Parity:0
// Correct for:	640:	Parity:0
// Correct for:	641:	Parity:1
// Correct for:	642:	Parity:1
// Correct for:	643:	Parity:0
// Correct for:	644:	Parity:1
// Correct for:	645:	Parity:0
// Correct for:	646:	Parity:0
// Correct for:	647:	Parity:1
// Correct for:	648:	Parity:1
// Correct for:	649:	Parity:0
// Correct for:	650:	Parity:0
// Correct for:	651:	Parity:1
// Correct for:	652:	Parity:0
// Correct for:	653:	Parity:1
// Correct for:	654:	Parity:1
// Correct for:	655:	Parity:0
// Correct for:	656:	Parity:1
// Correct for:	657:	Parity:0
// Correct for:	658:	Parity:0
// Correct for:	659:	Parity:1
// Correct for:	660:	Parity:0
// Correct for:	661:	Parity:1
// Correct for:	662:	Parity:1
// Correct for:	663:	Parity:0
// Correct for:	664:	Parity:0
// Correct for:	665:	Parity:1
// Correct for:	666:	Parity:1
// Correct for:	667:	Parity:0
// Correct for:	668:	Parity:1
// Correct for:	669:	Parity:0
// Correct for:	670:	Parity:0
// Correct for:	671:	Parity:1
// Correct for:	672:	Parity:1
// Correct for:	673:	Parity:0
// Correct for:	674:	Parity:0
// Correct for:	675:	Parity:1
// Correct for:	676:	Parity:0
// Correct for:	677:	Parity:1
// Correct for:	678:	Parity:1
// Correct for:	679:	Parity:0
// Correct for:	680:	Parity:0
// Correct for:	681:	Parity:1
// Correct for:	682:	Parity:1
// Correct for:	683:	Parity:0
// Correct for:	684:	Parity:1
// Correct for:	685:	Parity:0
// Correct for:	686:	Parity:0
// Correct for:	687:	Parity:1
// Correct for:	688:	Parity:0
// Correct for:	689:	Parity:1
// Correct for:	690:	Parity:1
// Correct for:	691:	Parity:0
// Correct for:	692:	Parity:1
// Correct for:	693:	Parity:0
// Correct for:	694:	Parity:0
// Correct for:	695:	Parity:1
// Correct for:	696:	Parity:1
// Correct for:	697:	Parity:0
// Correct for:	698:	Parity:0
// Correct for:	699:	Parity:1
// Correct for:	700:	Parity:0
// Correct for:	701:	Parity:1
// Correct for:	702:	Parity:1
// Correct for:	703:	Parity:0
// Correct for:	704:	Parity:1
// Correct for:	705:	Parity:0
// Correct for:	706:	Parity:0
// Correct for:	707:	Parity:1
// Correct for:	708:	Parity:0
// Correct for:	709:	Parity:1
// Correct for:	710:	Parity:1
// Correct for:	711:	Parity:0
// Correct for:	712:	Parity:0
// Correct for:	713:	Parity:1
// Correct for:	714:	Parity:1
// Correct for:	715:	Parity:0
// Correct for:	716:	Parity:1
// Correct for:	717:	Parity:0
// Correct for:	718:	Parity:0
// Correct for:	719:	Parity:1
// Correct for:	720:	Parity:0
// Correct for:	721:	Parity:1
// Correct for:	722:	Parity:1
// Correct for:	723:	Parity:0
// Correct for:	724:	Parity:1
// Correct for:	725:	Parity:0
// Correct for:	726:	Parity:0
// Correct for:	727:	Parity:1
// Correct for:	728:	Parity:1
// Correct for:	729:	Parity:0
// Correct for:	730:	Parity:0
// Correct for:	731:	Parity:1
// Correct for:	732:	Parity:0
// Correct for:	733:	Parity:1
// Correct for:	734:	Parity:1
// Correct for:	735:	Parity:0
// Correct for:	736:	Parity:0
// Correct for:	737:	Parity:1
// Correct for:	738:	Parity:1
// Correct for:	739:	Parity:0
// Correct for:	740:	Parity:1
// Correct for:	741:	Parity:0
// Correct for:	742:	Parity:0
// Correct for:	743:	Parity:1
// Correct for:	744:	Parity:1
// Correct for:	745:	Parity:0
// Correct for:	746:	Parity:0
// Correct for:	747:	Parity:1
// Correct for:	748:	Parity:0
// Correct for:	749:	Parity:1
// Correct for:	750:	Parity:1
// Correct for:	751:	Parity:0
// Correct for:	752:	Parity:1
// Correct for:	753:	Parity:0
// Correct for:	754:	Parity:0
// Correct for:	755:	Parity:1
// Correct for:	756:	Parity:0
// Correct for:	757:	Parity:1
// Correct for:	758:	Parity:1
// Correct for:	759:	Parity:0
// Correct for:	760:	Parity:0
// Correct for:	761:	Parity:1
// Correct for:	762:	Parity:1
// Correct for:	763:	Parity:0
// Correct for:	764:	Parity:1
// Correct for:	765:	Parity:0
// Correct for:	766:	Parity:0
// Correct for:	767:	Parity:1
// Correct for:	768:	Parity:0
// Correct for:	769:	Parity:1
// Correct for:	770:	Parity:1
// Correct for:	771:	Parity:0
// Correct for:	772:	Parity:1
// Correct for:	773:	Parity:0
// Correct for:	774:	Parity:0
// Correct for:	775:	Parity:1
// Correct for:	776:	Parity:1
// Correct for:	777:	Parity:0
// Correct for:	778:	Parity:0
// Correct for:	779:	Parity:1
// Correct for:	780:	Parity:0
// Correct for:	781:	Parity:1
// Correct for:	782:	Parity:1
// Correct for:	783:	Parity:0
// Correct for:	784:	Parity:1
// Correct for:	785:	Parity:0
// Correct for:	786:	Parity:0
// Correct for:	787:	Parity:1
// Correct for:	788:	Parity:0
// Correct for:	789:	Parity:1
// Correct for:	790:	Parity:1
// Correct for:	791:	Parity:0
// Correct for:	792:	Parity:0
// Correct for:	793:	Parity:1
// Correct for:	794:	Parity:1
// Correct for:	795:	Parity:0
// Correct for:	796:	Parity:1
// Correct for:	797:	Parity:0
// Correct for:	798:	Parity:0
// Correct for:	799:	Parity:1
// Correct for:	800:	Parity:1
// Correct for:	801:	Parity:0
// Correct for:	802:	Parity:0
// Correct for:	803:	Parity:1
// Correct for:	804:	Parity:0
// Correct for:	805:	Parity:1
// Correct for:	806:	Parity:1
// Correct for:	807:	Parity:0
// Correct for:	808:	Parity:0
// Correct for:	809:	Parity:1
// Correct for:	810:	Parity:1
// Correct for:	811:	Parity:0
// Correct for:	812:	Parity:1
// Correct for:	813:	Parity:0
// Correct for:	814:	Parity:0
// Correct for:	815:	Parity:1
// Correct for:	816:	Parity:0
// Correct for:	817:	Parity:1
// Correct for:	818:	Parity:1
// Correct for:	819:	Parity:0
// Correct for:	820:	Parity:1
// Correct for:	821:	Parity:0
// Correct for:	822:	Parity:0
// Correct for:	823:	Parity:1
// Correct for:	824:	Parity:1
// Correct for:	825:	Parity:0
// Correct for:	826:	Parity:0
// Correct for:	827:	Parity:1
// Correct for:	828:	Parity:0
// Correct for:	829:	Parity:1
// Correct for:	830:	Parity:1
// Correct for:	831:	Parity:0
// Correct for:	832:	Parity:1
// Correct for:	833:	Parity:0
// Correct for:	834:	Parity:0
// Correct for:	835:	Parity:1
// Correct for:	836:	Parity:0
// Correct for:	837:	Parity:1
// Correct for:	838:	Parity:1
// Correct for:	839:	Parity:0
// Correct for:	840:	Parity:0
// Correct for:	841:	Parity:1
// Correct for:	842:	Parity:1
// Correct for:	843:	Parity:0
// Correct for:	844:	Parity:1
// Correct for:	845:	Parity:0
// Correct for:	846:	Parity:0
// Correct for:	847:	Parity:1
// Correct for:	848:	Parity:0
// Correct for:	849:	Parity:1
// Correct for:	850:	Parity:1
// Correct for:	851:	Parity:0
// Correct for:	852:	Parity:1
// Correct for:	853:	Parity:0
// Correct for:	854:	Parity:0
// Correct for:	855:	Parity:1
// Correct for:	856:	Parity:1
// Correct for:	857:	Parity:0
// Correct for:	858:	Parity:0
// Correct for:	859:	Parity:1
// Correct for:	860:	Parity:0
// Correct for:	861:	Parity:1
// Correct for:	862:	Parity:1
// Correct for:	863:	Parity:0
// Correct for:	864:	Parity:0
// Correct for:	865:	Parity:1
// Correct for:	866:	Parity:1
// Correct for:	867:	Parity:0
// Correct for:	868:	Parity:1
// Correct for:	869:	Parity:0
// Correct for:	870:	Parity:0
// Correct for:	871:	Parity:1
// Correct for:	872:	Parity:1
// Correct for:	873:	Parity:0
// Correct for:	874:	Parity:0
// Correct for:	875:	Parity:1
// Correct for:	876:	Parity:0
// Correct for:	877:	Parity:1
// Correct for:	878:	Parity:1
// Correct for:	879:	Parity:0
// Correct for:	880:	Parity:1
// Correct for:	881:	Parity:0
// Correct for:	882:	Parity:0
// Correct for:	883:	Parity:1
// Correct for:	884:	Parity:0
// Correct for:	885:	Parity:1
// Correct for:	886:	Parity:1
// Correct for:	887:	Parity:0
// Correct for:	888:	Parity:0
// Correct for:	889:	Parity:1
// Correct for:	890:	Parity:1
// Correct for:	891:	Parity:0
// Correct for:	892:	Parity:1
// Correct for:	893:	Parity:0
// Correct for:	894:	Parity:0
// Correct for:	895:	Parity:1
// Correct for:	896:	Parity:1
// Correct for:	897:	Parity:0
// Correct for:	898:	Parity:0
// Correct for:	899:	Parity:1
// Correct for:	900:	Parity:0
// Correct for:	901:	Parity:1
// Correct for:	902:	Parity:1
// Correct for:	903:	Parity:0
// Correct for:	904:	Parity:0
// Correct for:	905:	Parity:1
// Correct for:	906:	Parity:1
// Correct for:	907:	Parity:0
// Correct for:	908:	Parity:1
// Correct for:	909:	Parity:0
// Correct for:	910:	Parity:0
// Correct for:	911:	Parity:1
// Correct for:	912:	Parity:0
// Correct for:	913:	Parity:1
// Correct for:	914:	Parity:1
// Correct for:	915:	Parity:0
// Correct for:	916:	Parity:1
// Correct for:	917:	Parity:0
// Correct for:	918:	Parity:0
// Correct for:	919:	Parity:1
// Correct for:	920:	Parity:1
// Correct for:	921:	Parity:0
// Correct for:	922:	Parity:0
// Correct for:	923:	Parity:1
// Correct for:	924:	Parity:0
// Correct for:	925:	Parity:1
// Correct for:	926:	Parity:1
// Correct for:	927:	Parity:0
// Correct for:	928:	Parity:0
// Correct for:	929:	Parity:1
// Correct for:	930:	Parity:1
// Correct for:	931:	Parity:0
// Correct for:	932:	Parity:1
// Correct for:	933:	Parity:0
// Correct for:	934:	Parity:0
// Correct for:	935:	Parity:1
// Correct for:	936:	Parity:1
// Correct for:	937:	Parity:0
// Correct for:	938:	Parity:0
// Correct for:	939:	Parity:1
// Correct for:	940:	Parity:0
// Correct for:	941:	Parity:1
// Correct for:	942:	Parity:1
// Correct for:	943:	Parity:0
// Correct for:	944:	Parity:1
// Correct for:	945:	Parity:0
// Correct for:	946:	Parity:0
// Correct for:	947:	Parity:1
// Correct for:	948:	Parity:0
// Correct for:	949:	Parity:1
// Correct for:	950:	Parity:1
// Correct for:	951:	Parity:0
// Correct for:	952:	Parity:0
// Correct for:	953:	Parity:1
// Correct for:	954:	Parity:1
// Correct for:	955:	Parity:0
// Correct for:	956:	Parity:1
// Correct for:	957:	Parity:0
// Correct for:	958:	Parity:0
// Correct for:	959:	Parity:1
// Correct for:	960:	Parity:0
// Correct for:	961:	Parity:1
// Correct for:	962:	Parity:1
// Correct for:	963:	Parity:0
// Correct for:	964:	Parity:1
// Correct for:	965:	Parity:0
// Correct for:	966:	Parity:0
// Correct for:	967:	Parity:1
// Correct for:	968:	Parity:1
// Correct for:	969:	Parity:0
// Correct for:	970:	Parity:0
// Correct for:	971:	Parity:1
// Correct for:	972:	Parity:0
// Correct for:	973:	Parity:1
// Correct for:	974:	Parity:1
// Correct for:	975:	Parity:0
// Correct for:	976:	Parity:1
// Correct for:	977:	Parity:0
// Correct for:	978:	Parity:0
// Correct for:	979:	Parity:1
// Correct for:	980:	Parity:0
// Correct for:	981:	Parity:1
// Correct for:	982:	Parity:1
// Correct for:	983:	Parity:0
// Correct for:	984:	Parity:0
// Correct for:	985:	Parity:1
// Correct for:	986:	Parity:1
// Correct for:	987:	Parity:0
// Correct for:	988:	Parity:1
// Correct for:	989:	Parity:0
// Correct for:	990:	Parity:0
// Correct for:	991:	Parity:1
// Correct for:	992:	Parity:1
// Correct for:	993:	Parity:0
// Correct for:	994:	Parity:0
// Correct for:	995:	Parity:1
// Correct for:	996:	Parity:0
// Correct for:	997:	Parity:1
// Correct for:	998:	Parity:1
// Correct for:	999:	Parity:0
